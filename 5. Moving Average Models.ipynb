# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.tsa.api as tsa
from pmdarima.arima.utils import ndiffs
from pmdarima.model_selection import train_test_split

# %%
def plot_forecast(ts_train, ts_test, forecast_df, n_train_lags=None, 
                  figsize=(10,4), title='Comparing Forecast vs. True Data'):
    ### PLot training data, and forecast (with upper/,lower ci)
    fig, ax = plt.subplots(figsize=figsize)
    # setting the number of train lags to plot if not specified
    if n_train_lags==None:
        n_train_lags = len(ts_train)
            
    # Plotting Training  and test data
    ts_train.iloc[-n_train_lags:].plot(ax=ax, label="train")
    ts_test.plot(label="test", ax=ax)
    # Plot forecast
    forecast_df['mean'].plot(ax=ax, color='green', label="forecast")
    # Add the shaded confidence interval
    ax.fill_between(forecast_df.index, 
                    forecast_df['mean_ci_lower'],
                   forecast_df['mean_ci_upper'],
                   color='green', alpha=0.3,  lw=2)
    # set the title and add legend
    ax.set_title(title)
    ax.legend();
    
    return fig, ax

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
def regression_metrics_ts(ts_true, ts_pred, label="", verbose=True, output_dict=False,):
    # Get metrics
    mae = mean_absolute_error(ts_true, ts_pred)
    mse = mean_squared_error(ts_true, ts_pred)
    rmse = mean_squared_error(ts_true, ts_pred, squared=False)
    r_squared = r2_score(ts_true, ts_pred)
    mae_perc = mean_absolute_percentage_error(ts_true, ts_pred) * 100
    if verbose == True:
        # Print Result with label
        header = "---" * 20
        print(header, f"Regression Metrics: {label}", header, sep="\n")
        print(f"- MAE = {mae:,.3f}")
        print(f"- MSE = {mse:,.3f}")
        print(f"- RMSE = {rmse:,.3f}")
        print(f"- R^2 = {r_squared:,.3f}")
        print(f"- MAPE = {mae_perc:,.2f}%")
    if output_dict == True:
        metrics = {
            "Label": label,
            "MAE": mae,
            "MSE": mse,
            "RMSE": rmse,
            "R^2": r_squared,
            "MAPE(%)": mae_perc,
        }
        return metrics

# %%
# Custom function for Ad Fuller Test
def get_adfuller_results(ts, alpha=.05, label='adfuller', **kwargs): #kwargs for adfuller()
    # Saving each output
    (test_stat, pval, nlags, nobs, crit_vals_d, 
    icbest ) = tsa.adfuller(ts, **kwargs)
    # Converting output to a dictionary with the interpretation of p
    adfuller_results = {'Test Statistic': test_stat,
                        "# of Lags Used":nlags, 
                       '# of Observations':nobs,
                        'p-value': round(pval,6),
                        'alpha': alpha,
                       'sig/stationary?': pval < alpha}
    return pd.DataFrame(adfuller_results, index =[label])

# %%
# Load in data
ts = pd.read_csv('Data/MA_lesson_ts.csv', index_col = 'date')
ts.head()
# Out:
#                value
# date
# 2000-01-31  0.332798
# 2000-02-29  0.057122
# 2000-03-31  0.691783
# 2000-04-30  1.132335
# 2000-05-31  0.692867

# %%
# We have monthly data so we will set our frequency to M
ts.index.freq= "M"
# Define the series
ts = ts['value']

# %%
# Check for nulls
ts.isna().sum()
# Out:
# 0

# %%
# Plot the time series
ts.plot();

# %%
# Make acf plot of raw data to look for seasonality
tsa.graphics.plot_acf(ts);

# %%
# Check for stationarity

# Call custom function to check to see if data is stationary
get_adfuller_results(ts)
# Out:
#           Test Statistic  # of Lags Used  # of Observations   p-value  alpha  \
# adfuller       -4.254855               9                190  0.000531   0.05
#
#           sig/stationary?
# adfuller             True

# %%
# check differencing with ndiffs
d = ndiffs(ts)
print (f'd = {d}')
# Out:
# d = 0

# %%
# Determining the MA Order Using Autocorrelation

### NEW FUNCTION FOR COMBINED ACF/PACF WITH ANNOTATIONS
def plot_acf_pacf(ts, nlags=40, figsize=(10, 5), 
                  annotate_sig=False, alpha=.05,
                 acf_kws={}, pacf_kws={},  
                  annotate_seas=False, m = None,
                 seas_color='black'):
    
    fig, axes = plt.subplots(nrows=2, figsize=figsize)
    
    # Sig lags line style
    sig_vline_kwargs = dict( ls=':', lw=1, zorder=0, color='red')
    # ACF
    tsa.graphics.plot_acf(ts, ax=axes[0], lags=nlags, **acf_kws)
    
    ## Annotating sig acf lags
    if annotate_sig == True:
        sig_acf_lags = get_sig_lags(ts,nlags=nlags,alpha=alpha, type='ACF')
        for lag in sig_acf_lags:
            axes[0].axvline(lag,label='sig', **sig_vline_kwargs )
    # PACF
    tsa.graphics.plot_pacf(ts,ax=axes[1], lags=nlags, **pacf_kws)
    
    ## Annotating sig pacf lags
    if annotate_sig == True:
        ## ANNOTATING SIG LAGS
        sig_pacf_lags = get_sig_lags(ts,nlags=nlags,alpha=alpha, type='PACF')
        for lag in sig_pacf_lags:
            axes[1].axvline(lag, label='sig', **sig_vline_kwargs)
    
    ### ANNOTATE SEASONS
    if annotate_seas == True:
        # Ensure m was defined
        if m is None:
            raise Exception("Must define value of m if annotate_seas=True.")
        ## Calculate number of complete seasons to annotate
        n_seasons = nlags//m 
        # Seasonal Lines style
        seas_vline_kwargs = dict( ls='--',lw=1, alpha=.7, color=seas_color, zorder=-1)
        
        ## for each season, add a line
        for i in range(1, n_seasons+1):
            axes[0].axvline(m*i, **seas_vline_kwargs, label="season")
            axes[1].axvline(m*i, **seas_vline_kwargs, label="season")
    fig.tight_layout()
    
    return fig

# %%
# Let's call our custom acf/pacf plot on our stationary (d = 0) data
plot_acf_pacf(ts);

# %%
# tts
train, test = train_test_split(ts, test_size=.20)
# Visualize the train and test data
ax = train.plot(label='Train')
test.plot(ax=ax, label='Test')
ax.legend()

# %%
# MA only Model

# First define the orders (p,d,q)
p = 0 # p is us ed for AR models (set to 0 for an MA only model)
d = 0 # no differcing was required to make the data stationary
q = 2 # q based on significant lags in ACF
# Now instantiate the model with the data and fit
ma_2_model = tsa.ARIMA(train, order = (p,d,q)).fit()
ma_2_model
# Out:
# /Users/sofiawang/anaconda3/envs/dojo-env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# /Users/sofiawang/anaconda3/envs/dojo-env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# /Users/sofiawang/anaconda3/envs/dojo-env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)

# %%
# Obtain the parameters of the fit model
ma_2_model.params
# Out:
# const    -0.105130
# ma.L1     0.446952
# ma.L2     0.946894
# sigma2    0.379158
# dtype: float64

# %%
# Obtain forecast as a dataframe with confidence intervals
forecast_df = ma_2_model.get_forecast(steps=len(test)).summary_frame()
# Call the custom function to plot the forecasts with confidence intervals and true values
plot_forecast(train, test, forecast_df);

# %%
# Combining AR & MA models

# Load in data
ts = pd.read_csv('Data/MA_lesson_ts.csv', parse_dates = ['date'], index_col = 'date')
ts.head()
# Out:
#                value
# date
# 2000-01-31  0.332798
# 2000-02-29  0.057122
# 2000-03-31  0.691783
# 2000-04-30  1.132335
# 2000-05-31  0.692867

# %%
# We have daily data so we will set our frequency to D
ts.index.freq= "D"
ts.index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/dojo-env/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py:1008, in DatetimeLikeArrayMixin._validate_frequency(cls, index, freq, **kwargs)
#    1007     if not np.array_equal(index.asi8, on_freq.asi8):
# -> 1008         raise ValueError
#    1009 except ValueError as e:
#
# ValueError:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # We have daily data so we will set our frequency to D
# ----> 2 ts.index.freq= "D"
#       3 ts.index
#
# File ~/anaconda3/envs/dojo-env/lib/python3.10/site-packages/pandas/core/indexes/extension.py:81, in _inherit_from_data.<locals>.fset(self, value)
#      80 def fset(self, value):
# ---> 81     setattr(self._data, name, value)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py:937, in DatetimeLikeArrayMixin.freq(self, value)
#     935 if value is not None:
#     936     value = to_offset(value)
# --> 937     self._validate_frequency(self, value)
#     939     if self.ndim > 1:
#     940         raise ValueError("Cannot set freq with ndim > 1")
#
# File ~/anaconda3/envs/dojo-env/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py:1019, in DatetimeLikeArrayMixin._validate_frequency(cls, index, freq, **kwargs)
#    1013     raise e
#    1014 # GH#11587 the main way this is reached is if the `np.array_equal`
#    1015 #  check above is False.  This can also be reached if index[0]
#    1016 #  is `NaT`, in which case the call to `cls._generate_range` will
#    1017 #  raise a ValueError, which we re-raise with a more targeted
#    1018 #  message.
# -> 1019 raise ValueError(
#    1020     f"Inferred frequency {inferred} from passed values "
#    1021     f"does not conform to passed frequency {freq.freqstr}"
#    1022 ) from e
#
# ValueError: Inferred frequency M from passed values does not conform to passed frequency D

# %%
# Check for nulls
ts.isna().sum().sum()
# Out:
# 0

# %%
# Plot the time series
ts.plot();

# %%
# Call custom function to check to see if data is stationary
get_adfuller_results(ts)
# Out:
#           Test Statistic  # of Lags Used  # of Observations   p-value  alpha  \
# adfuller       -4.254855               9                190  0.000531   0.05
#
#           sig/stationary?
# adfuller             True

# %%
# Check to see how many differencing are needed
ndiffs(ts)
# Out:
# 0

# %%
# We need to apply differencing one time
ts_diff = ts.diff().dropna()
# Confirm stationarity with adfuller test
get_adfuller_results(ts_diff)
# Out:
#           Test Statistic  # of Lags Used  # of Observations  p-value  alpha  \
# adfuller        -6.90768              10                188      0.0   0.05
#
#           sig/stationary?
# adfuller             True

# %%
# Let's call our custom acf/pacf plot on our stationary (d = 1) data
plot_acf_pacf(ts_diff);

# %%
# First define the orders (p,d,q)
p = 1 # p is used for AR component of AR-MA model
d = 1 # 1 differcing needed to make stationary
q = 1 # q is used for MA component of AR-MA model
# Now instantiate the model with the data and fit
ar_ma_model = tsa.ARIMA(train, order = (p,d,q)).fit()
ar_ma_model
# Out:
# /Users/sofiawang/anaconda3/envs/dojo-env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# /Users/sofiawang/anaconda3/envs/dojo-env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# /Users/sofiawang/anaconda3/envs/dojo-env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)

# %%
# Obtain the parameters of the fit model
ar_ma_model.params
# Out:
# ar.L1    -0.629612
# ma.L1     0.144928
# sigma2    0.670682
# dtype: float64
